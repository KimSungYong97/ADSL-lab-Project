# %%
# %matplotlib inline
import pandas as pd                # 데이터를 저장하고 처리하는 패키지
import matplotlib as mpl           # 그래프를 그리는 패키지
import matplotlib.pyplot as plt    # 그래프를 그리는 패키지
import numpy as np
plt.rcParams["figure.figsize"] = (14,4)

# %%
df1 = pd.read_csv('WHO-COVID-19-global-data.csv',encoding='CP949')
df2 = pd.read_csv('세계 GDP.csv',encoding='CP949')
df3 = pd.read_csv('무역의존도.csv',encoding='CP949')

# %%
c_list =list(['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States'])

# %% [markdown]
# 코로나 현황

# %%
df1_1=pd.pivot_table(df1,index='Date_reported',columns=' Country',values=' Cumulative_cases')

# %%
df1_1.plot()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %% [markdown]
# 1961~2020 세계 GDP 추이

# %%
#df2 = df2[['Country','EDITION', 'FREQUENCY','TIME','Value']]
#df2=df2[(df2['SUBJECT']=='B1_GE')&(df2['Measure']=='Growth rate compared to previous quarter, seasonally adjusted')]
df2=pd.pivot_table(df2,index='TIME',columns='Country',values='Value')
df2=df2.loc[:,['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
df2['Mean'] = df2.mean(axis=1)

# %%
df2.plot()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
df2['Mean'].plot()
plt.axhline(y=0, color='r', linewidth=1)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
df2[df2['Mean']<0.5]
# Out:
# Country  Argentina  Australia    Austria    Belgium     Brazil  Bulgaria  \
# TIME
# 1975-Q1        NaN  -0.354341  -1.044334  -0.581805        NaN       NaN
# 1975-Q2        NaN   4.908399  -1.649343  -2.814653        NaN       NaN
# 1975-Q3        NaN   2.528222  -1.165648  -2.482813        NaN       NaN
# 1982-Q4        NaN  -2.155539   2.079607  -0.120160        NaN       NaN
# 2008-Q4  -2.555404   1.652337  -1.421501  -2.258376   1.032711  4.222525
# 2009-Q1  -6.965056   1.552044  -3.625779  -3.625919  -1.561377 -1.511603
# 2009-Q2  -9.521415   1.892520  -5.342942  -3.641015  -1.908588 -2.791453
# 2009-Q3  -6.722447   1.418146  -4.319595  -1.849736  -1.139859 -3.155991
# 2009-Q4  -0.236996   2.657668  -1.719047   1.131079   5.365627 -6.444459
# 2020-Q1  -4.645285   1.560467  -3.015278  -2.031198  -1.428837  2.263517
# 2020-Q2 -19.770307  -6.256519 -14.464516 -13.876917 -11.387498 -8.574156
# 2020-Q3  -9.000000  -3.000000  -5.296425  -5.142582  -5.000000 -5.181406
#
# Country     Canada      Chile  China   Colombia  ...  Slovak Republic  \
# TIME                                             ...
# 1975-Q1  -0.094838        NaN    NaN        NaN  ...              NaN
# 1975-Q2   0.108100        NaN    NaN        NaN  ...              NaN
# 1975-Q3   2.077805        NaN    NaN        NaN  ...              NaN
# 1982-Q4  -4.069450        NaN    NaN        NaN  ...              NaN
# 2008-Q4   0.088076   0.924401    7.1   0.462402  ...         0.975713
# 2009-Q1  -2.248518  -2.567173    6.4   0.444834  ...        -5.970252
# 2009-Q2  -3.663661  -3.169667    8.2   0.800094  ...        -5.650563
# 2009-Q3  -4.017307  -1.305710   10.6   0.282773  ...        -5.424973
# 2009-Q4  -1.758874   0.849598   11.9   3.048442  ...        -4.799983
# 2020-Q1  -0.909460   0.400054   -6.8   0.980362  ...        -3.821989
# 2020-Q2 -13.013588 -13.682773    3.2 -15.450147  ...       -12.114778
# 2020-Q3  -4.581313  -6.000000    4.9  -7.000000  ...        -2.244499
#
# Country   Slovenia  South Africa      Spain    Sweden  Switzerland     Turkey  \
# TIME
# 1975-Q1        NaN      1.148133   1.533484  5.206673    -7.633498        NaN
# 1975-Q2        NaN      1.496719   0.183236  2.251150    -8.898761        NaN
# 1975-Q3        NaN      1.163622  -0.084209  1.749971    -7.696547        NaN
# 1982-Q4        NaN     -3.854637   1.829180  3.101433    -2.362027        NaN
# 2008-Q4  -1.141771      1.309038  -1.475770 -4.915390    -0.729398  -5.762222
# 2009-Q1  -6.994005     -0.684149  -4.249451 -5.368580    -3.119719 -12.933908
# 2009-Q2  -9.472146     -2.218756  -4.364256 -5.350117    -3.372189  -6.113517
# 2009-Q3  -8.760713     -2.225654  -3.985541 -5.043350    -2.651287  -2.085238
# 2009-Q4  -5.349813     -1.010150  -2.430337 -1.043180     1.006873   2.428115
# 2020-Q1  -3.549662     -0.217267  -4.159114  0.679792    -0.671797   4.416187
# 2020-Q2 -13.107421    -17.212737 -21.507740 -7.736886    -8.248531  -8.983860
# 2020-Q3  -6.000000     -8.000000  -8.723952 -4.057333    -4.000000  -4.000000
#
# Country  United Kingdom  United States       Mean
# TIME
# 1975-Q1        0.634931      -2.299060   0.054686
# 1975-Q2       -2.419926      -1.834261   0.080612
# 1975-Q3       -3.363664       0.798682   0.489799
# 1982-Q4        2.187560      -1.443154   0.394234
# 2008-Q4       -3.615799      -2.753083  -1.424958
# 2009-Q1       -5.749361      -3.289072  -4.502566
# 2009-Q2       -5.398946      -3.924447  -4.606849
# 2009-Q3       -3.778531      -3.049780  -3.696061
# 2009-Q4       -1.417699       0.182874  -1.261550
# 2020-Q1       -2.076543       0.319261  -0.578305
# 2020-Q2      -21.462009      -9.032775 -11.016880
# 2020-Q3       -9.577713      -2.913841  -4.446915
#
# [12 rows x 48 columns]

# %% [markdown]
# 75 1차 오일쇼크, 82 2차 오일쇼크, 08 리먼사태, 20 코로나

# %% [markdown]
# 코로나 사태 GDP 와 순위

# %%
covid = df2.loc[['2020-Q1','2020-Q2']]
covid_mean = -100+100*((100+covid.loc['2020-Q1'])/100)*((100+covid.loc['2020-Q2'])/100)
covid_mean.plot(kind='bar')
c_mean=covid_mean['Mean']

# %%
c_mean=covid_mean['Mean']

# %% [markdown]
# 리먼 사태 GDP 와 순위

# %%
lehman=df2.loc[['2008-Q3','2008-Q4']]
lehman_mean = -100+(100+lehman.loc['2008-Q3'])*(100+lehman.loc['2008-Q4'])/(100)
lehman_mean.plot(kind='bar')
l_mean=lehman_mean['Mean']

# %%
#lehman_mean.rank(ascending=False)
lehman_mean.sort_values()
# Out:
# Country
# Latvia            -14.257269
# Estonia           -14.196591
# Ireland           -11.206742
# Luxembourg         -6.666932
# Turkey             -5.750024
# Sweden             -5.132974
# Italy              -4.848026
# United Kingdom     -4.662074
# Japan              -4.629469
# Denmark            -4.397977
# Iceland            -3.315879
# United States      -2.751258
# New Zealand        -2.375334
# Finland            -2.167215
# Greece             -2.139922
# Belgium            -1.951562
# France             -1.836623
# Germany            -1.450544
# Norway             -1.389918
# Portugal           -1.316813
# Lithuania          -1.236133
# Spain              -0.703079
# Hungary            -0.462656
# Austria             0.259694
# Mean                0.443784
# Mexico              0.494687
# Canada              1.466571
# Slovenia            1.729673
# Netherlands         2.095786
# Czech Republic      2.153783
# South Korea         2.293432
# Switzerland         2.484628
# Argentina           2.726984
# Israel              2.822983
# Russia              3.365768
# Colombia            3.903733
# Australia           4.355931
# Chile               4.421406
# South Africa        4.685397
# Poland              5.494662
# Slovak Republic     7.179709
# Brazil              7.665968
# India               8.829927
# Bulgaria           10.623061
# Indonesia          11.674966
# Romania            15.363949
# China              17.274500
# Saudi Arabia             NaN
# dtype: float64

# %%
lehman=df2.loc[['2008-Q2']]
lehman_mean = -100+(100+lehman.loc['2008-Q2'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Ireland            -3.592925
# Estonia            -1.620428
# Greece             -1.147594
# Latvia             -1.093308
# Luxembourg         -0.548222
# Japan              -0.152409
# Italy              -0.002340
# New Zealand         0.360630
# France              0.536426
# Portugal            0.835148
# Denmark             0.972251
# Canada              0.974880
# Sweden              1.004911
# United States       1.092428
# Norway              1.149365
# United Kingdom      1.253179
# Germany             1.557136
# Mexico              1.578277
# Belgium             1.682570
# Spain               1.744398
# Finland             2.071978
# Iceland             2.149912
# Hungary             2.441870
# Turkey              2.460997
# Austria             2.775305
# Australia           3.000419
# Mean                3.027727
# Netherlands         3.327803
# Switzerland         3.796843
# Czech Republic      3.916990
# South Africa        4.294481
# South Korea         4.315217
# Israel              4.331700
# Colombia            4.342515
# Chile               4.379327
# Lithuania           4.632293
# Poland              5.295236
# Slovenia            5.559327
# Argentina           6.029257
# Brazil              6.031217
# Indonesia           6.274600
# Bulgaria            6.329884
# India               6.974690
# Slovak Republic     7.166823
# Russia              8.940648
# China              10.900000
# Romania            10.951749
# Saudi Arabia             NaN
# Name: 2008-Q2, dtype: float64

# %%
lehman=df2.loc[['2008-Q3']]
lehman_mean = -100+(100+lehman.loc['2008-Q3'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Latvia             -6.802521
# Luxembourg         -1.729904
# Estonia            -1.708762
# Italy              -1.368930
# United Kingdom     -1.085526
# Ireland            -1.016612
# Japan              -0.900927
# New Zealand        -0.663820
# Greece             -0.624738
# Denmark            -0.551895
# Norway             -0.314673
# Sweden             -0.228833
# France             -0.109575
# United States       0.001877
# Turkey              0.012944
# Belgium             0.313904
# Germany             0.410829
# Iceland             0.500777
# Portugal            0.544806
# Lithuania           0.632081
# Finland             0.779242
# Spain               0.784264
# Mexico              1.257004
# Canada              1.377281
# Hungary             1.687571
# Austria             1.705438
# Mean                1.895756
# Netherlands         2.061055
# Israel              2.462688
# Australia           2.659648
# Czech Republic      2.671577
# Slovenia            2.904609
# Poland              3.189570
# Switzerland         3.237641
# South Africa        3.332733
# Colombia            3.425491
# Chile               3.464975
# South Korea         3.946152
# Russia              5.001309
# Argentina           5.420915
# India               6.003420
# Indonesia           6.055767
# Bulgaria            6.141221
# Slovak Republic     6.144048
# Brazil              6.565456
# China               9.500000
# Romania            10.115188
# Saudi Arabia             NaN
# Name: 2008-Q3, dtype: float64

# %%
lehman=df2.loc[['2008-Q4']]
lehman_mean = -100+(100+lehman.loc['2008-Q4'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Estonia           -12.704926
# Ireland           -10.294788
# Latvia             -7.998873
# Turkey             -5.762222
# Luxembourg         -5.023937
# Sweden             -4.915390
# Denmark            -3.867426
# Iceland            -3.797638
# Japan              -3.762439
# United Kingdom     -3.615799
# Italy              -3.527384
# Finland            -2.923674
# United States      -2.753083
# Argentina          -2.555404
# Belgium            -2.258376
# Hungary            -2.114542
# Lithuania          -1.856479
# Germany            -1.853758
# Portugal           -1.851532
# France             -1.728942
# New Zealand        -1.722950
# South Korea        -1.589978
# Russia             -1.557639
# Greece             -1.524709
# Spain              -1.475770
# Mean               -1.424958
# Austria            -1.421501
# Slovenia           -1.141771
# Norway             -1.078639
# Mexico             -0.752854
# Switzerland        -0.729398
# Czech Republic     -0.504320
# Netherlands         0.034029
# Canada              0.088076
# Israel              0.351635
# Colombia            0.462402
# Chile               0.924401
# Slovak Republic     0.975713
# Brazil              1.032711
# South Africa        1.309038
# Australia           1.652337
# Poland              2.233842
# India               2.666430
# Bulgaria            4.222525
# Romania             4.766609
# Indonesia           5.298344
# China               7.100000
# Saudi Arabia             NaN
# Name: 2008-Q4, dtype: float64

# %%
lehman=df2.loc[['2009-Q1']]
lehman_mean = -100+(100+lehman.loc['2009-Q1'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Lithuania         -14.054785
# Estonia           -13.054940
# Latvia            -13.051778
# Turkey            -12.933908
# Iceland            -9.341777
# Japan              -8.597868
# Finland            -8.405151
# Russia             -7.484284
# Hungary            -7.227671
# Italy              -7.188815
# Germany            -7.029257
# Slovenia           -6.994005
# Argentina          -6.965056
# Greece             -6.770291
# Ireland            -6.723702
# Luxembourg         -5.973104
# Slovak Republic    -5.970252
# United Kingdom     -5.749361
# Mexico             -5.629876
# Sweden             -5.368580
# Denmark            -5.196422
# Mean               -4.502566
# Czech Republic     -4.348723
# Portugal           -4.328947
# Spain              -4.249451
# Romania            -3.982617
# Netherlands        -3.875672
# France             -3.793499
# Belgium            -3.625919
# Austria            -3.625779
# United States      -3.289072
# Switzerland        -3.119719
# Chile              -2.567173
# New Zealand        -2.477522
# Canada             -2.248518
# South Korea        -1.896187
# Brazil             -1.561377
# Bulgaria           -1.511603
# South Africa       -0.684149
# Norway             -0.647406
# Israel             -0.464620
# India               0.164170
# Colombia            0.444834
# Australia           1.552044
# Poland              1.893807
# Indonesia           4.435945
# China               6.400000
# Saudi Arabia             NaN
# Name: 2009-Q1, dtype: float64

# %%
lehman=df2.loc[['2009-Q2']]
lehman_mean = -100+(100+lehman.loc['2009-Q2'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Estonia           -16.802344
# Lithuania         -15.751751
# Latvia            -14.973984
# Argentina          -9.521415
# Slovenia           -9.472146
# Russia             -9.397149
# Finland            -9.319627
# Mexico             -7.743736
# Hungary            -7.730421
# Luxembourg         -7.041286
# Iceland            -6.847851
# Germany            -6.643278
# Italy              -6.615952
# Japan              -6.326814
# Romania            -6.223749
# Denmark            -6.168268
# Turkey             -6.113517
# Slovak Republic    -5.650563
# United Kingdom     -5.398946
# Czech Republic     -5.351162
# Sweden             -5.350117
# Austria            -5.342942
# Ireland            -4.941833
# Mean               -4.606849
# Spain              -4.364256
# Netherlands        -4.344447
# United States      -3.924447
# Portugal           -3.769342
# Canada             -3.663661
# Belgium            -3.641015
# Greece             -3.564516
# France             -3.437867
# Switzerland        -3.372189
# Chile              -3.169667
# Bulgaria           -2.791453
# South Africa       -2.218756
# New Zealand        -2.107038
# Brazil             -1.908588
# Norway             -1.570363
# South Korea        -1.106362
# Israel              0.096125
# Colombia            0.800094
# Poland              1.693639
# Australia           1.892520
# Indonesia           4.202840
# India               4.882530
# China               8.200000
# Saudi Arabia             NaN
# Name: 2009-Q2, dtype: float64

# %%
lehman=df2.loc[['2009-Q3']]
lehman_mean = -100+(100+lehman.loc['2009-Q3'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Estonia           -18.453896
# Latvia            -15.745701
# Lithuania         -14.337385
# Slovenia           -8.760713
# Finland            -7.840617
# Russia             -7.648640
# Hungary            -7.556643
# Argentina          -6.722447
# Romania            -6.242635
# Ireland            -5.776615
# Germany            -5.540702
# Slovak Republic    -5.424973
# Denmark            -5.290600
# Czech Republic     -5.127096
# Japan              -5.103683
# Sweden             -5.043350
# Mexico             -5.038824
# Italy              -5.038755
# Luxembourg         -4.627308
# Austria            -4.319595
# Greece             -4.170677
# Canada             -4.017307
# Spain              -3.985541
# Netherlands        -3.843695
# United Kingdom     -3.778531
# Mean               -3.696061
# Bulgaria           -3.155991
# United States      -3.049780
# France             -2.983818
# Portugal           -2.840185
# Iceland            -2.742053
# Switzerland        -2.651287
# South Africa       -2.225654
# Turkey             -2.085238
# Belgium            -1.849736
# Norway             -1.326588
# New Zealand        -1.306329
# Chile              -1.305710
# Brazil             -1.139859
# Colombia            0.282773
# South Korea         1.028927
# Israel              1.099716
# Australia           1.418146
# Poland              2.627207
# Indonesia           4.389441
# India               6.633140
# China              10.600000
# Saudi Arabia             NaN
# Name: 2009-Q3, dtype: float64

# %%
lehman=df2.loc[['2009-Q4']]
lehman_mean = -100+(100+lehman.loc['2009-Q4'])
lehman_mean.plot(kind='bar')
lehman_mean.sort_values()
# Out:
# Country
# Lithuania         -14.592243
# Latvia            -13.412261
# Iceland            -8.011084
# Estonia            -7.128920
# Finland            -6.700016
# Bulgaria           -6.444459
# Slovenia           -5.349813
# Slovak Republic    -4.799983
# Romania            -4.665737
# Hungary            -4.244838
# Russia             -3.511662
# Germany            -3.293834
# Czech Republic     -3.216696
# Denmark            -2.911942
# Greece             -2.688349
# Netherlands        -2.621880
# Ireland            -2.500893
# Spain              -2.430337
# Italy              -2.319887
# Mexico             -1.831485
# Canada             -1.758874
# Austria            -1.719047
# Norway             -1.582413
# Portugal           -1.521659
# United Kingdom     -1.417699
# Japan              -1.404903
# Mean               -1.261550
# Sweden             -1.043180
# South Africa       -1.010150
# France             -0.895240
# Argentina          -0.236996
# United States       0.182874
# Luxembourg          0.348547
# New Zealand         0.723051
# Chile               0.849598
# Switzerland         1.006873
# Belgium             1.131079
# Turkey              2.428115
# Australia           2.657668
# Colombia            3.048442
# Israel              3.160159
# Poland              4.663012
# South Korea         5.239425
# Brazil              5.365627
# Indonesia           5.763113
# India               8.767620
# China              11.900000
# Saudi Arabia             NaN
# Name: 2009-Q4, dtype: float64

# %%
l_mean=lehman_mean['Mean']

# %%
plt.figure(figsize=(12,12))
plt.xlabel('$Covid$',fontsize=14)
plt.ylabel('$Lehman$',fontsize=14)
plt.scatter(covid_mean, lehman_mean)
for i, txt in enumerate(c_list):
    plt.annotate(txt, (covid_mean[i], lehman_mean[i]))
plt.axvline(x=c_mean, color='r', linewidth=1)
plt.axhline(y=l_mean, color='r', linewidth=1)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(14,4))
df1['c_per_p']=df1[' Cumulative_cases']/df1['Population']
df1_1=pd.pivot_table(df1,index='Date_reported',columns=' Country',values=' Cumulative_cases')
df1_2=pd.pivot_table(df1,index='Date_reported',columns=' Country',values='c_per_p')
df1_2['Mean'] = df1_2.mean(axis=1)
df1_1['Mean'] = df1_1.mean(axis=1)
d1_2mean=df1_2['Mean']
d1_1mean=df1_1['Mean']
df1_2.plot()
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# %%
c_per_p2=df1_2.loc['2020-07-01',['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
c_per_p1=df1_1.loc['2020-07-01',['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]

# %%
from matplotlib import style
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

style.use('seaborn-talk')

# %%
X_min=0
X_max=0.015
X_n=l_mean
def show_line(w1,w2):
    xb=np.linspace(X_min,X_max,100)
    y=w1*xb+w2
    plt.plot(xb,y,color=(.5,.5,.5),linewidth=4)
def show_line2(w1,w2):
    xb=np.linspace(X_min,X_max,100)
    y=w1*xb+w2
    plt.plot(xb,y,color='w',linewidth=4)

# %%
def mse_line(x,t,w):
    y=w[0]*x+w[1]
    mse=np.mean((y-t)**2)
    #mse=np.mean(np.abs(y-t))
    return mse
def standard_deviation(mse):
    return mse**(1/2)
def dmse_line(x,t,w):
    y=w[0]*x+w[1]
    d_w0=2*np.mean((y-t)*x)
    d_w1=2*np.mean(y-t)
    return d_w0,d_w1
def fit_line_num(x,t):
    w_init=[10.0,10.0]
    alpha=0.0001
    i_max=100000
    eps=0.1
    w_i=np.zeros([i_max,2])
    w_i[0,:]=w_init
    for i in range(1,i_max):
        dmse=dmse_line(x,t,w_i[i-1])
        w_i[i,0]=w_i[i-1,0]-alpha*dmse[0]
        w_i[i,1]=w_i[i-1,1]-alpha*dmse[1]
        if max(np.absolute(dmse))<eps:
            break
    
    w0=w_i[i,0]
    w1=w_i[i,1]
    w_i=w_i[:i,:]
    return w0,w1
def fit_line(x,t):
    mx=np.mean(x)
    mt=np.mean(t)
    mtx=np.mean(t*x)
    mxx=np.mean(x*x)
    w0=(mtx-mt*mx)/(mxx-mx**2)
    w1=mt - w0*mx
    return np.array([w0,w1])
def show_data2(ax,x0,x1,t):
    for i in range(len(x0)):
        ax.plot([x0[i],x0[i]],[x1[i],x1[i]],[120,t[i]],color='gray')
        ax.plot(x0,x1,t,'o',color='cornflowerblue',markeredgecolor='black',markersize=6,markeredgewidth=0.5)
        ax.view_init(elev=35,azim=-75)

# %%
T=covid_mean[0:47]
X=c_per_p2[0:47]

W0,W1=fit_line(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$COVID$',fontsize=14)
plt.ylabel('$GDP$',fontsize=14)
show_line(W0,W1)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')
plt.title('COVID Confirmed person & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
plt.grid(True)
plt.show()

# %%
print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))
# Out:
# Mean=-11.488355
# MSE=41.505992
# standard error=6.442514
# standard error/Mean=-0.560786

# %%
T=covid_mean[0:47]
X=c_per_p2[0:47]

W0,W1=fit_line(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$COVID$',fontsize=14)
plt.ylabel('$GDP$',fontsize=14)
show_line2(W0,W1)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')
plt.title('COVID Confirmed person & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
plt.grid(True)
plt.show()

# %%
np.shape(c_per_p2[0:47])
# Out:
# (47,)

# %%
df3 = pd.read_csv('무역의존도.csv',encoding='CP949')
df3=df3.set_index('Country')

# %%
df3['2019 무역']=df3['2019 수출']+df3['2019 수입']
df3['2007 무역']=df3['2007 수출']+df3['2007 수입']

# %%
trp1=df3['2019 무역']
trp2=df3['2007 무역']

# %%
X_min=10
X_max=170

# %%
df6 = pd.read_csv('의료종사자수.csv',encoding='CP949')
df6=df6.set_index('Country')
df6['천명당 의료진']=(df6['천명당 의사']+df6['천명당 간호사'])
t_per_d=df6['천명당 의료진']

# %%
"""covid_mean=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
trp1=trp1.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
covid_mean2=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States']]
t_per_d=t_per_d.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
t_per_d2=t_per_d.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States']]
c_list =list(['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States'])
c_list2=list(['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States'])
covid_mean3=covid_mean.loc[['Argentina','Australia','Austria','Brazil','Bulgaria','Canada','Chile','China','Colombia','Denmark','Estonia','Finland','France','Germany','Greece','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Lithuania','Luxembourg','Norway','Poland','Portugal','Russia','Saudi Arabia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
trp1_2=trp1.loc[['Argentina','Australia','Austria','Brazil','Bulgaria','Canada','Chile','China','Colombia','Denmark','Estonia','Finland','France','Germany','Greece','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Lithuania','Luxembourg','Norway','Poland','Portugal','Russia','Saudi Arabia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
c_list3=list(['Argentina','Australia','Austria','Brazil','Bulgaria','Canada','Chile','China','Colombia','Denmark','Estonia','Finland','France','Germany','Greece','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Lithuania','Luxembourg','Norway','Poland','Portugal','Russia','Saudi Arabia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States'])
"""
# Out:
# "covid_mean=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]\ntrp1=trp1.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]\ncovid_mean2=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States']]\nt_per_d=t_per_d.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]\nt_per_d2=t_per_d.loc[['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States']]\nc_list =list(['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States'])\nc_list2=list(['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Czech Republic','Denmark','Finland','France','Greece','Hungary','India','Indonesia','Ireland','Italy','Japan','Lithuania','Netherlands','Poland','Portugal','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Turkey','United Kingdom','United States'])\ncovid_mean3=covid_mean.loc[['Argentina','Australia','Austria','Brazil','Bulgaria','Canada','Chile','China','Colombia','Denmark','Estonia','Finland','France','Germany','Greece','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Lithuania','Luxembourg','Norway','Poland','Portugal','Russia','Saudi Arabia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]\ntrp1_2=trp1.loc[['Argentina','Australia','Austria','Brazil','Bulgaria','Canada','Chile','China','Colombia','Denmark','Estonia','Finland','France','Germany','Greece','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Lithuania','Luxembourg','Norw ...

# %%
"""covid_mean=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States']]
trp1=trp1.loc[['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States']]
c_list =list(['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States'])
"""
# Out:
# "covid_mean=covid_mean.loc[['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States']]\ntrp1=trp1.loc[['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States']]\nc_list =list(['Argentina','Australia','Austria','Belgium','Brazil','Canada','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','India','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Netherlands','New Zealand','Norway','Poland','Portugal','Slovenia','Spain','Sweden','Switzerland','United Kingdom','United States'])\n"

# %%
X_min=20
X_max=170

# %%
T=covid_mean[0:47]
X=trp1[0:47]
W0,W1=fit_line(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$2019 Dependence on trade$',fontsize=14)
plt.ylabel('$2020 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')
show_line2(W0,W1)
plt.title('COVID Dependence on trade & GDP')
for i, txt in enumerate(c_list[0:47]):
    plt.annotate(txt, (X[i], T[i]))
#plt.axvline(x=covid_mean, color='r', linewidth=1)
#plt.axhline(y=T.mean(), color='r', linewidth=1)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.xlabel('$2019 Dependence on trade$',fontsize=14)
plt.ylabel('$2020 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')
show_line(W0,W1)
plt.title('COVID Dependence on trade & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
#plt.axvline(x=covid_mean[47], color='r', linewidth=1)
#plt.axhline(y=T.mean(), color='r', linewidth=1)
"""print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))"""
plt.grid(True)
plt.show()

# %%
print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))
# Out:
# Mean=-11.488355
# MSE=44.453867
# standard error=6.667373
# standard error/Mean=-0.580359

# %%
X.plot(kind='bar')
X.sort_values()
# Out:
# Country
# United States       19.34
# Brazil              22.27
# Argentina           25.40
# Japan               28.08
# India               28.15
# Colombia            28.48
# Israel              34.21
# Australia           35.35
# United Kingdom      39.53
# New Zealand         39.57
# France              44.96
# Norway              46.79
# Greece              47.76
# Italy               50.28
# Spain               50.61
# Canada              52.48
# Finland             54.69
# Luxembourg          56.96
# Denmark             59.50
# Sweden              60.16
# South Korea         63.51
# Portugal            66.03
# Ireland             69.25
# Pomania             69.51
# Germany             70.82
# Switzerland         71.08
# Austria             78.21
# Poland              88.82
# Latvia              95.80
# Estonia            108.72
# Lithuania          126.77
# Hungary            148.02
# Netherlands        148.05
# Czech Republic     153.57
# Belgium            164.62
# Slovenia           165.28
# Bulgaria              NaN
# Chile                 NaN
# China                 NaN
# Iceland               NaN
# Indonesia             NaN
# Mexico                NaN
# Russia                NaN
# Saudi Arabia          NaN
# Slovak Republic       NaN
# South Africa          NaN
# Turkey                NaN
# Name: 2019 무역, dtype: float64

# %%
X_min=0
X_max=25

# %%
T=covid_mean[0:47]
X=t_per_d

W0,W1=fit_line(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$2018 Medical staff$',fontsize=14)
plt.ylabel('$2020 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')

show_line(W0,W1)
plt.title('COVID Medical staff & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
#plt.axvline(x=covid_mean[47], color='r', linewidth=1)
#plt.axhline(y=T.mean(), color='r', linewidth=1)
"""print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))"""
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.xlabel('$2018 Medical staff$',fontsize=14)
plt.ylabel('$2020 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')

show_line(W0,W1)
plt.title('COVID Medical staff & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
#plt.axvline(x=covid_mean[47], color='r', linewidth=1)
#plt.axhline(y=T.mean(), color='r', linewidth=1)
"""print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))"""
plt.grid(True)
plt.show()

# %%
print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/T.mean()))
# Out:
# Mean=-11.488355
# MSE=35.173249
# standard error=5.930704
# standard error/Mean=-0.516236

# %%
X_min=20
X_max=170

# %%
T=lehman_mean[0:47]
X=trp2[0:47]

W0,W1=fit_line_num(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$2007 Dependence on trade$',fontsize=14)
plt.ylabel('$2008 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')

show_line2(W0,W1)
plt.title('Lehman Dependence on trade & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
plt.axvline(x=lehman_mean[47], color='r', linewidth=1)
plt.axhline(y=T.mean(), color='r', linewidth=1)
print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/c_per_p2[0:47].mean()))
plt.grid(True)
plt.show()
# Out:
# Mean=-1.261550
# MSE=20.395582
# standard error=4.516147
# standard error/Mean=1629.143198

# %%
T=lehman_mean[0:47]
X=trp2[0:47]

W0,W1=fit_line(X,T)
plt.figure(figsize=(12,12))
plt.xlabel('$2007 Dependence on trade$',fontsize=14)
plt.ylabel('$2008 GDP$',fontsize=14)
plt.plot(X,T,marker='o',linestyle='None',markeredgecolor='black',color='cornflowerblue')

show_line(W0,W1)
plt.title('Lehman Dependence on trade & GDP')
for i, txt in enumerate(c_list):
    plt.annotate(txt, (X[i], T[i]))
plt.axvline(x=lehman_mean[47], color='r', linewidth=1)
plt.axhline(y=T.mean(), color='r', linewidth=1)
print('Mean={0:.6f}'.format(T.mean()))
print('MSE={0:.6f}'.format(mse_line(X,T,[W0,W1])))
print('standard error={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))))
print('standard error/Mean={0:.6f}'.format(standard_deviation(mse_line(X,T,[W0,W1]))/c_per_p2[0:47].mean()))
plt.grid(True)
plt.show()
# Out:
# Mean=-1.261550
# MSE=20.395392
# standard error=4.516126
# standard error/Mean=1629.135602

# %%
covid_mean2=covid_mean.loc[:,['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-51-dc82ef654eb0> in <module>
# ----> 1 covid_mean2=covid_mean.loc[:,['Argentina','Australia','Austria','Belgium','Brazil','Bulgaria','Canada','Chile','China','Colombia','Czech Republic','Denmark','Estonia','Finland','France','Germany','Greece','Hungary','Iceland','India','Indonesia','Ireland','Israel','Italy','Japan','South Korea','Latvia','Lithuania','Luxembourg','Mexico','Netherlands','New Zealand','Norway','Poland','Portugal','Romania','Russia','Saudi Arabia','Slovak Republic','Slovenia','South Africa','Spain','Sweden','Switzerland','Turkey','United Kingdom','United States']]
#
# c:\users\ksy\anaconda3\envs\py368\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\users\ksy\anaconda3\envs\py368\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1047
#    1048         # no multi-index, so validate all of the indexers
# -> 1049         self._has_valid_tuple(tup)
#    1050
#    1051         # ugly hack for GH #836
#
# c:\users\ksy\anaconda3\envs\py368\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     698         for i, k in enumerate(key):
#     699             if i >= self.ndim:
# --> 700                 raise IndexingError("Too many indexers")
#     701             try:
#     702                 self._validate_key(k, i)
#
# IndexingError: Too many indexers
